# %%
# %matplotlib inline
import numpy as np
import os
from scipy import misc
from skimage import io, color,exposure  ##sudo apt-get install python-skimage
import cv2
import matplotlib.pyplot as plt

os.chdir('/home/manu/gits/')
import beijbom_vision_lib.misc.tools as bmt

imfile='/home/manu/Documents/temp/150150017.jpg'
im=misc.imread(imfile)

plt.imshow(im)
plt.show()

#simple hist stretch
im2=bmt.hist_stretch(im)
plt.imshow(im2)
plt.show()

im3=cv2.cvtColor(im,cv2.COLOR_BGR2HSV)
hist,bins = np.histogram(im3[:,:,2],256,[0,256])
cdf = hist.cumsum()
cdf_m = np.ma.masked_equal(cdf,0)
cdf_m = (cdf_m - cdf_m.min())*255/(cdf_m.max()-cdf_m.min())
cdf = np.ma.filled(cdf_m,0).astype('uint8')
#print(cdf)

color=('h','s','v')
for channel,col in enumerate(color):
    print channel
    print col
    histr = cv2.calcHist([im3],[channel],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.title('Histogram for color scale picture')
plt.show()


#ualize_adapthist(im)
#im3=cv2.imread(imfile,0)
#im3 = cv2.equalizeHist(im3)
#im3=color.hsv2rgb(im3)
#plt.imshow(im3)
#plt.show()
# Out:
# 0
# h
# 1
# s
# 2
# v

# %%
cdf=cv2.calcHist([im3],[0,1,2],None,[360,256,256],[0,360,0,256,0,256])
cdf_m = np.ma.masked_equal(cdf,0)
cdf_m = (cdf_m - cdf_m.min())/(cdf_m.max()-cdf_m.min())
cdf = np.ma.filled(cdf_m,0).astype('uint32')
#print(cdf)

#plt.imshow(cdf)
#plt.show()

# %%
channels=3
for i in [1,2]:
    im4=im3
    hist,bins = np.histogram(im3[:,:,i],256,[0,256])
    cdf = hist.cumsum()
    cdf_m = np.ma.masked_equal(cdf,0)
    cdf_m = (cdf_m - cdf_m.min())*255/(cdf_m.max()-cdf_m.min())
    cdf = np.ma.filled(cdf_m,0).astype('uint8')
    im4[:,:,1]=cdf[im3[:,:,i]]

#print(im4)

# %%
im3=cv2.cvtColor(im,cv2.COLOR_RGB2HSV)
im3[:,:,1]=cv2.equalizeHist(im3[:,:,1])
im3[:,:,2]=cv2.equalizeHist(im3[:,:,2])
plt.imshow(cv2.cvtColor(im3,cv2.COLOR_HSV2RGB))

#plt.show()
hist,bins = np.histogram(im3.flatten(), 256,[0,256])
#plt.plot(hist, lw=2)
#plt.imshow(im3)
#plt.show()
